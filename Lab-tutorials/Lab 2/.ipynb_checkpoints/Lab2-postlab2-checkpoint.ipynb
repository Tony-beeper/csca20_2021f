# %%
import matplotlib.pyplot as plt
import random

start = int(input("Choose a start year"))
end = int(input("Choose an end year"))
cm = plt.get_cmap('PuRd')

NUM_COLORS = end-start+1
plot = plt.figure()
ax = plot.add_subplot(111)
ax.set_prop_cycle(color = [cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])

months = ["Jan", "Feb", "Mar", "Apr", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

plt.title("Temperature Yea!!!", fontdict = {'fontname': 'Comic Sans MS', 'fontsize':20})
plt.xlabel('Months')
plt.ylabel('Temperature °C')

for year in range(start, end+1):
    year_temp = []
    for month in range(0,12):
        month_temp = int(input("Please enter the average temperature in "+str(months[month]+" of "+ str(year))))
        year_temp.append(month_temp)
    ax.plot(months, year_temp, label = str(year), marker = 'o', markersize=6)
    ax.legend(loc = "upper left")
    plt.tight_layout()
plt.show()
# Out:
# Choose a start year 2017
# Choose an end year 2021
# Please enter the average temperature in Jan of 2017 15
# Please enter the average temperature in Feb of 2017 16
# Please enter the average temperature in Mar of 2017 17
# Please enter the average temperature in Apr of 2017 18
# Please enter the average temperature in May of 2017 13
# Please enter the average temperature in June of 2017 14
# Please enter the average temperature in July of 2017 15
# Please enter the average temperature in Aug of 2017 12
# Please enter the average temperature in Sept of 2017 13
# Please enter the average temperature in Oct of 2017 1
# Please enter the average temperature in Nov of 2017 15
# Please enter the average temperature in Dec of 2017 16
# Please enter the average temperature in Jan of 2018 2
# Please enter the average temperature in Feb of 2018 13
# Please enter the average temperature in Mar of 2018 14
# Please enter the average temperature in Apr of 2018 15
# Please enter the average temperature in May of 2018 7
# Please enter the average temperature in June of 2018 8
# Please enter the average temperature in July of 2018 6
# Please enter the average temperature in Aug of 2018 14
# Please enter the average temperature in Sept of 2018 12
# Please enter the average temperature in Oct of 2018 13
# Please enter the average temperature in Nov of 2018 14
# Please enter the average temperature in Dec of 2018 12
# Please enter the average temperature in Jan of 2019 15
# Please enter the average temperature in Feb of 2019 5
# Please enter the average temperature in Mar of 2019 6
# Please enter the average temperature in Apr of 2019 7
# Please enter the average temperature in May of 2019 8
# Please enter the average temperature in June of 2019 4
# Please enter the average temperature in July of 2019 14
# Please enter the average temperature in Aug of 2019 15
# Please enter the average temperature in Sept of 2019 16
# Please enter the average temperature in Oct of 2019 21
# Please enter the average temperature in Nov of 2019 20
# Please enter the average temperature in Dec of 2019 18
# Please enter the average temperature in Jan of 2020 19
# Please enter the average temperature in Feb of 2020 12
# Please enter the average temperature in Mar of 2020 13
# Please enter the average temperature in Apr of 2020 14
# Please enter the average temperature in May of 2020 15
# Please enter the average temperature in June of 2020 12
# Please enter the average temperature in July of 2020 13
# Please enter the average temperature in Aug of 2020 14
# Please enter the average temperature in Sept of 2020 15
# Please enter the average temperature in Oct of 2020 16
# Please enter the average temperature in Nov of 2020 7
# Please enter the average temperature in Dec of 2020 6
# Please enter the average temperature in Jan of 2021 5
# Please enter the average temperature in Feb of 2021 7
# Please enter the average temperature in Mar of 2021 6
# Please enter the average temperature in Apr of 2021 5
# Please enter the average temperature in May of 2021 12
# Please enter the average temperature in June of 2021 10
# Please enter the average temperature in July of 2021 15
# Please enter the average temperature in Aug of 2021 12
# Please enter the average temperature in Sept of 2021 14
# Please enter the average temperature in Oct of 2021 15
# Please enter the average temperature in Nov of 2021 10
# Please enter the average temperature in Dec of 2021 7
