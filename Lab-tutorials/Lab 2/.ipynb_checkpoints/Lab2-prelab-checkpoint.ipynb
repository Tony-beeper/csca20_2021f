# %%
import matplotlib.pyplot as plt

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]
temp = [0, -10, 2, 5, 10, 20, 22, 26, 15, 10, 5, 2]

    
plt.plot(months, temp)
plt.show()
